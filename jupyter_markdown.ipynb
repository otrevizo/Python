# %% [markdown]
# # Heading 1
# Text
#
# ## Heading 2
# Text
#
# ### Heading 3
# Text

# %% [markdown]
# # Highlighting, bold-facing, italics
#
# Text `highlighted codish within tick marks`, now more text.
#
# Text *within astherik it is italics*, now more text.
#
# Text _within underscore are also italics_, more text.
#
# Text **within double astherik is bold faced**, now more text.
#
# Outlining use numbers. Use number 1 only and the computer does the rest.

# %% [markdown]
# # Listing
#
# ## Numbered lists
#
# 1. First line item
# 1. Second line item
# 1. Third line item
#
# Now sub-line items. And sub-tems get letter automtically.
#
# 1. First line item
#     1. First sub-item
#     1. Second sub-item
#     1. Third sub-item
# 1. Second line item
#     1. First sub-item
#     1. Second sub-item
#     1. Third sub-item
# 1. Third line item
#     1. First sub-item
#     1. Second sub-item
#     1. Third sub-item
#
#
# ## Bullet points:
#
#  * Bullet point one
#  * Bullet point two
#  * Bullet point three

# %% [markdown]
# # Mathematics
#
# Add a linefeed between each line. Otherwise it runs like one long line.
#
# $x$-coordinates
#
# $y$-coordinates
#
# $(x_i, y_i)$
#
# Sample sizes $N$
#
# Code from `function()` calls
#
# Standard Error of the Mean is $SEM=\frac{\sigma}{\sqrt{N}}$
#
# $\sigma$
#
# $F(x)$
#
# $f(x)$
#
# $R^2$
#
# $X_i$
#
# $x_1$, $x_2$
#
# Sum symbols, with sigma:
#
# $s=\sum_1^Nx_i=x_1+\ldots+x_N$
#
# $y=ax+b$
#
# $S=X_1+X_2+\ldots+X_N, \;\; X_i \;\; \text{i.i.d.}$
#
# Notice the double dollar sign sends the text to the middle.
#
# $$S=X_1+X_2+\ldots+X_N, \;\; X_i \;\; \text{i.i.d.}$$
#
# $N=1$
#
# $x_1, \ldots, x_N$
#
# $X_1, \ldots, X_N$
#
# $p=1+k+k*(k+1)/2$
#
# $[0;1]$
#
# $\{1,2\}$
#
# $\hat{x}$, $\tilde{x}$, $\vec{x}$, $\widehat{h}$
#
# Also check this page https://rpruim.github.io/s341/S19/from-class/MathinRmd.html

# %% [markdown]
# # Greek Letters
#
# alpha	$\alpha A$
#
# beta	$\beta B$
#
# gamma	$\gamma \Gamma$
#
# delta	$\delta \Delta$
#
# epsilon	$\epsilon \varepsilon E$
#
# zeta	$\zeta Z \sigma \,\!$
#
# eta	$\eta H$
#
# theta	$\theta \vartheta \Theta$
#
# iota	$\iota I$
#
# kappa	$\kappa K$
#
# lambda	$\lambda \Lambda$
#
# mu	$\mu M$
#
# nu	$\nu N$
#
# xi	$\xi\Xi$
#
# omicron	$o O$ (omicron)
#
# pi	$\pi \Pi$
#
# rho	$\rho\varrho P$
#
# sigma	$\sigma \Sigma$
#
# tau	$\tau T$
#
# upsilon	$\upsilon \Upsilon$
#
# phi	$\phi \varphi \Phi$
#
# chi	$\chi X$
#
# psi	$\psi \Psi$
#
# omega	$\omega \Omega$

# %% [markdown]
# # Colored text, lines
#
# <p style="color:blue">Blue text.</p>
#
# <p style="color:red">Red text.</p>
#
# Horizontal rule is:
# ---

# %% [markdown]
# # Code documented
#
# ```
# {
#   "one": 1,
#   "two": 2,
#   "three": 3
# }
# ```

# %% [markdown]
# # Links and images
#
# [Google](http://www.google.com)
#
# ![this is me](me_pizza.png)

# %% [markdown]
# # Statistics, null hypothesis wording
#
#
# The $p-value$ is extremely low $<2e-16$. The null hypothesis is; *there is no association between the two variables.* The alternative hypothesis is; _there is association between the two variables._ A very low $p-value$ indicates that the null hypotheses $H_0$ is not plausible.
#
# $Y=B_0+B_1X+e$
#
# The coefficients are $B_0$ and $B_1$, while $e$ is a residual error.
#
# $H_0$: There is no relationship between $X$ and $Y$
#
# $H_a$: There is some relationship between $X$ and $Y$
#
# $H_0$: $B_1 = 0$
#
# versus
#
# $H_a$: $B_1 \neq 0$
#
# The very a small *p-value* indicates that we can *reject* the null hypothesis. That allows us to infer that _"there is an association between the predictor and the response"_ (ISLR p.68).
#
# And the results from `summary(lm(...))` shows *three asteriscks* next to the *p-value* indicating that the relationship is statistically **significant.** One would need to do additional tests on an additional data samples if possible to make sure the conclusion is not tied to this specific dataset. Therefore, **there is statistically significant association between these two variables, `contrib` and `lastcontr`,** based on this summary.

# %% [markdown]
# # References
#
# * Markdown GitHub: https://rpruim.github.io/s341/S19/from-class/MathinRmd.html
# * Stackoverflow reliable online coding tips: https://stackoverflow.com/

# %% [markdown]
# # Pledge of integrity
#
# Pledge of integrity: The code presented in this assignment is based on material from **the course** plus additional sources listed in the References. My code here is intended for my own use and reference. I did not discuss it or shared it with any student in class or anyone outside of my class. I am not posting or sharing any of **the course** solutions or excerpts with anyone.
