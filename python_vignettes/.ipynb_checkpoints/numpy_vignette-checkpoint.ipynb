# %%
# -*- coding: utf-8 -*-
"""
Created on 2022-12-20
Revised on 2026-04-01

@author:       Oscar Trevizo
@institution:  Harvard Extension School — Graduate Data Science Program (2023)
@context:      Independent project — applying course concepts to real-world data
@environment:  Python 3.14.3 | myenv | MacBook Air M5

NumPy Vignette
==============

Description:
    Demonstrates core NumPy operations: array creation from lists,
    descriptive statistics (mean, corrcoef), array indexing, element-wise
    arithmetic, and random array generation with np.random.randint.

References:
    - NumPy documentation: https://numpy.org/doc/

Revision History:
    2022-12-20  Original development
                - np.array, mean(), corrcoef(), random.randint()
                - Array indexing and element-wise math
                - 2D array creation and shape inspection

    2026-04-01  Sabbatical portfolio refresh
                - Added Cell [1] standard docstring
                - Verified compatibility with Python 3.14.3
                - No deprecated APIs found; code is clean
"""
# Out:
# '\nCreated on 2022-12-20\nRevised on 2026-04-01\n\n@author:       Oscar Trevizo\n@institution:  Harvard Extension School — Graduate Data Science Program (2023)\n@context:      Independent project — applying course concepts to real-world data\n@environment:  Python 3.14.3 | myenv | MacBook Air M5\n\nNumPy Vignette\n==============\n\nDescription:\n    Demonstrates core NumPy operations: array creation from lists,\n    descriptive statistics (mean, corrcoef), array indexing, element-wise\n    arithmetic, and random array generation with np.random.randint.\n\nReferences:\n    - NumPy documentation: https://numpy.org/doc/\n\nRevision History:\n    2022-12-20  Original development\n                - np.array, mean(), corrcoef(), random.randint()\n                - Array indexing and element-wise math\n                - 2D array creation and shape inspection\n\n    2026-04-01  Sabbatical portfolio refresh\n                - Added Cell [1] standard docstring\n                - Verified compa
# ...

# %% [markdown]
# # NumPy Vignette
#
# December 20, 2022
#
# Vignette: NumPy
#
# @author: Oscar A. Trevizo
#
# ### References
# 1. "NumPy documentation" (accessed Dec. 20, 2022)
#     https://numpy.org/doc/

# %%
import numpy as np

# %%
# Explore the library
# np.__dict__

# %% [markdown]
# # Load data

# %%
# Two more numeric lists we can compare
score_1_list = [91, 83, 95, 72, 91, 85, 89, 82, 90, 79]
score_2_list = [91, 85, 90, 81, 95, 92, 88, 94, 91, 75]

# %% [markdown]
# # Instantiate NumPy objects

# %%
sc1 = np.array(score_1_list)
sc2 = np.array(score_2_list)

# %% [markdown]
# # Apply NumPy methods

# %%
sc1.mean()
# Out:
# np.float64(85.7)

# %%
sc2.mean()
# Out:
# np.float64(88.2)

# %%
np.corrcoef(sc1,sc2)
# Out:
# array([[1.        , 0.64929131],
#        [0.64929131, 1.        ]])

# %% [markdown]
# # Array operations

# %%
# Points
sc1[4]
# Out:
# np.int64(91)

# %%
# Math
sc_mean = (sc1+sc2)/2
sc_mean
# Out:
# array([91. , 84. , 92.5, 76.5, 93. , 88.5, 88.5, 88. , 90.5, 77. ])

# %% [markdown]
# # Create NumPy random arrays

# %%
# 2D array
new_array = np.array([np.random.randint(50,100,20),np.random.randint(10,200,20)])
new_array
# Out:
# array([[ 86,  85,  84,  60,  57,  95,  94,  73,  99,  62,  52,  93,  67,
#          81,  86,  56,  68,  74,  76,  84],
#        [ 75, 168,  61, 118, 183, 166,  42,  73, 126, 172, 143,  49, 135,
#          63, 111, 120,  19,  43, 154,  61]])

# %%
new_array.shape
# Out:
# (2, 20)
