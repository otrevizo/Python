# %%
# -*- coding: utf-8 -*-
"""
Created on 2021-11-13
Revised on 2026-04-01

@author:       Oscar Trevizo
@institution:  Harvard Extension School — Graduate Data Science Program (2023)
@context:      Independent project — applying course concepts to real-world data
@environment:  Python 3.14.3 | myenv | MacBook Air M5

Python Lambdas Vignette
========================

Description:
    Demonstrates Python lambda (anonymous) functions. Covers one-liner
    syntax, assigning lambdas to variables for reuse, iterating over
    numpy arrays with lambdas, and multi-argument lambdas.

    Syntax:  lambda args: expression
    Example: (lambda x, y: x + y)(val_x, val_y)

References:
    - Python Tutorial: https://docs.python.org/3/tutorial/controlflow.html
    - NumPy: https://numpy.org/doc/stable/reference/generated/numpy.array.html
    - VanderPlas, J. 'Python Data Science Handbook', O'Reilly Media 2016
    - VanderPlas, J. 'A Whirlwind Tour of Python', O'Reilly Media 2016

Revision History:
    2021-11-13  Original development
                - Simple one-liner lambdas
                - Reusable lambda assigned to variable
                - Iteration over numpy arrays
                - Multi-argument lambdas

    2026-04-01  Sabbatical portfolio refresh
                - Added Cell [1] standard docstring
                - Verified compatibility with Python 3.14.3
                - pandas and numpy imports confirmed compatible
                - No deprecated APIs found; code is clean
"""
# Out:
# "\nCreated on 2021-11-13\nRevised on 2026-04-01\n\n@author:       Oscar Trevizo\n@institution:  Harvard Extension School — Graduate Data Science Program (2023)\n@context:      Independent project — applying course concepts to real-world data\n@environment:  Python 3.14.3 | myenv | MacBook Air M5\n\nPython Lambdas Vignette\n========================\n\nDescription:\n    Demonstrates Python lambda (anonymous) functions. Covers one-liner\n    syntax, assigning lambdas to variables for reuse, iterating over\n    numpy arrays with lambdas, and multi-argument lambdas.\n\n    Syntax:  lambda args: expression\n    Example: (lambda x, y: x + y)(val_x, val_y)\n\nReferences:\n    - Python Tutorial: https://docs.python.org/3/tutorial/controlflow.html\n    - NumPy: https://numpy.org/doc/stable/reference/generated/numpy.array.html\n    - VanderPlas, J. 'Python Data Science Handbook', O'Reilly Media 2016\n    - VanderPlas, J. 'A Whirlwind Tour of Python', O'Reilly Media 2016\n\nRevision History:\n    2021-11-13  Original development\n                - Simple one-liner lambdas\n                - Reusable lambda assigned to variable\n                - Iteration over numpy arrays\n                - Multi-argument lambdas\n\n    2026-04-01  Sabbatical portfolio refresh\n                - Added Cell [1] standard docstring\n                - Verified compatibility with Python 3.14.3\n                - pandas and numpy imports confirmed compatible\n                - No deprecated APIs found; code is clean\n"

# %% [markdown]
# # Lambdas Vignette
#
# November 13, 2021
#
# Vignette: Lambdas functions
#
# @author: Oscar A. Trevizo
#
# One liners! Create a function all in one line.
#
# Syntax:
# (lambda args list: expression to execute)(args values)
#
# Example:
# (lambda x, y: x + y)(value_of_x, value_of_y)
#
# --> the arguments that lambda needs are defined before the colon ":"
# --> The expression that comes after the colon is the formula that lambda uses
#
# ### References
# * The Python Tutorial, https://docs.python.org/3/tutorial/
#     https://docs.python.org/3/tutorial/controlflow.html#defining-functions
#     https://docs.python.org/3/tutorial/datastructures.html
# * https://numpy.org/doc/stable/reference/generated/numpy.array.html
# * VanderPlas, J. "Python Data Science Handbook", O'Reilly Media 2016
# * VanderPlas, J. "A Whirlwind Tour of Python" O'Reilly Media 2016

# %% [markdown]
# # Lambdas

# %% [markdown]
# ## Import libraries

# %%
# Lambda does not need libraries. Just for these examples
import pandas as pd
import numpy as np

# %% [markdown]
# # Simple one liners

# %%
# Simple one-liner, add two numbers
(lambda x, y: x + y)(7, 2)
# Out:
# 9

# %%
# Same one-liner, and assign result to a variable
a = (lambda x, y: x + y)(7, 2)
print(a)
# Out:
# 9

# %% [markdown]
# # Re-using a lambda

# %%
# Now define a 'lambda' as nameless (on-the-fly) function that I can re-use
my_on_the_fly_square = lambda x: x ** 2

# %%
# Using my newly on-the-fly defined functions
b = my_on_the_fly_square(5)
print(b)
# Out:
# 25

# %%
my_on_the_fly_square(10)
# Out:
# 100

# %% [markdown]
# # Iterating

# %%
# Iterate my newly defined on-the-fly lambda function
# Will send an array of inegers using numpy.array
L = np.array([2, 3, 4])

# %%
# Now "L" will be used as an argumate that iterates my lambda function
c = my_on_the_fly_square(L)
print(c)
# Out:
# [ 4  9 16]

# %% [markdown]
# # Multiple arguments

# %%
# Now define a 'lambda' with two arguments
my_on_the_fly_power = lambda x, y: x ** y

# %%
# Supply an array of number to iterate, and the second argument
d = my_on_the_fly_power(L, 3)
print(d)
# Out:
# [ 8 27 64]

# %%
# Supply an array of number to iterate, and the second argument
e = my_on_the_fly_power(2, L)
print(e)
# Out:
# [ 4  8 16]
