# %%
# -*- coding: utf-8 -*-
"""
Created on 2022-03-28
Revised on 2026-04-01

@author:       Oscar Trevizo
@institution:  Harvard Extension School — Graduate Data Science Program (2023)
@context:      Independent project — applying course concepts to real-world data
@environment:  Python 3.14.3 | myenv | MacBook Air M5

Python Strings Vignette
========================

Description:
    Demonstrates Python string methods and patterns. Covers: iteration
    over strings, strip/lstrip/rstrip, find(), 'in' operator, split(),
    isalnum/isalpha/isdigit/islower/isupper/isspace, endswith/startswith,
    replace(), and list comprehensions applied to strings.

References:
    - https://docs.python.org/3/tutorial/datastructures.html
    - https://docs.python.org/3/library/stdtypes.html#string-methods
    - https://www.w3schools.com/python/python_lists_comprehension.asp
    - https://www.geeksforgeeks.org/python-list-comprehension/
    - VanderPlas, J. 'A Whirlwind Tour of Python', O'Reilly Media

Revision History:
    2022-03-28  Original development
                - String iteration, strip, find, split
                - is* methods: isalnum, isalpha, isdigit, islower, isupper
                - endswith, startswith, replace
                - List comprehensions on strings

    2026-04-01  Sabbatical portfolio refresh
                - Added Cell [1] standard docstring
                - Verified compatibility with Python 3.14.3
                - No deprecated APIs found; code is clean
"""
# Out:
# "\nCreated on 2022-03-28\nRevised on 2026-04-01\n\n@author:       Oscar Trevizo\n@institution:  Harvard Extension School — Graduate Data Science Program (2023)\n@context:      Independent project — applying course concepts to real-world data\n@environment:  Python 3.14.3 | myenv | MacBook Air M5\n\nPython Strings Vignette\n========================\n\nDescription:\n    Demonstrates Python string methods and patterns. Covers: iteration\n    over strings, strip/lstrip/rstrip, find(), 'in' operator, split(),\n    isalnum/isalpha/isdigit/islower/isupper/isspace, endswith/startswith,\n    replace(), and list comprehensions applied to strings.\n\nReferences:\n    - https://docs.python.org/3/tutorial/datastructures.html\n    - https://docs.python.org/3/library/stdtypes.html#string-methods\n    - https://www.w3schools.com/python/python_lists_comprehension.asp\n    - https://www.geeksforgeeks.org/python-list-comprehension/\n    - VanderPlas, J. 'A Whirlwind Tour of Python', O'Reilly Media\n\nRevision History:\n    2022-03-28  Original development\n                - String iteration, strip, find, split\n                - is* methods: isalnum, isalpha, isdigit, islower, isupper\n                - endswith, startswith, replace\n                - List comprehensions on strings\n\n    2026-04-01  Sabbatical portfolio refresh\n                - Added Cell [1] standard docstring\n                - Verified compatibility with Python 3.14.3\n                - No deprecated APIs found; code is clean\n"

# %% [markdown]
# # Python Strings Vignette
#
# March 28, 2022
#
# @author: Oscar A. Trevizo
#
# * Various methods on strings
#
# References:
# 1. https://docs.python.org/3/tutorial/datastructures.html
# 1. https://docs.python.org/3/library/stdtypes.html?highlight=strip#string-methods
# 1. https://docs.python.org/3/tutorial/datastructures.html#using-lists-as-stacks
# 1. https://www.w3schools.com/python/python_lists_comprehension.asp
# 1. https://www.geeksforgeeks.org/python-list-comprehension/
# 1. Whirlwind Tour of Python, Jake Varderplas
#
# Additional references included within the code below.

# %% [markdown]
# # Strings are iterators

# %%
# String are iterators. https://www.w3schools.com/python/python_iterators.asp
for x in 'orange':
    print(x, end = '-')
# Out:
# o-r-a-n-g-e-

# %% [markdown]
# ## String strip spaces, left, right, both

# %%
'   hello, world   '.strip()
# Out:
# 'hello, world'

# %%
'   hello, world   '.lstrip()
# Out:
# 'hello, world   '

# %%
'   hello, world   '.rstrip()
# Out:
# '   hello, world'

# %% [markdown]
# ## String find()
# Find location of substring, if it exists.

# %%
'hello, world'.find(' ')
# Out:
# 6

# %%
'hello, world'.find('w')
# Out:
# 7

# %%
# Alternative to find()
s = 'w'
if s in 'hello, world':
    print('loc of', s, 'is','hello, world'.find(s))
else:
    print(s, ' is not part of hello, world')
# Out:
# loc of w is 7

# %%
'hello, world'.find('x')
# Out:
# -1

# %%
# Alternative to find()
s = 'x'
if s in 'hello, world':
    print('loc of', s, 'is','hello, world'.find(s))
else:
    print(s, ' is not part of hello, world')
# Out:
# x  is not part of hello, world

# %%
'hello' in 'hello, world'
# Out:
# True

# %%
'x' in 'hello, world'
# Out:
# False

# %%
'hello, world'.find('orl')
# Out:
# 8

# %%
# Alternative to find()
s = 'orl'
if s in 'hello, world':
    print('loc of', s, 'is','hello, world'.find(s))
else:
    print(s, ' is not part of hello, world')
# Out:
# loc of orl is 8

# %% [markdown]
# # List with strings in it — call methods on its strings

# %%
# List comprehension example using also strings
# https://www.w3schools.com/python/python_lists_comprehension.asp
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
[x for x in fruits if "a" in x]
# Out:
# ['apple', 'banana', 'mango']

# %%
# https://www.w3schools.com/python/python_lists_comprehension.asp
[x for x in fruits if x != "apple"]
# Out:
# ['banana', 'cherry', 'kiwi', 'mango']

# %%
# call a string method on each element
freshfruit = ['  banana', '  loganberry ', 'passion fruit  ']

# %%
[s.strip() for s in freshfruit]
# Out:
# ['banana', 'loganberry', 'passion fruit']

# %% [markdown]
# # Make a list out of a string

# %%
# Make a list from a string
# https://www.geeksforgeeks.org/python-list-comprehension/
[char for char in 'hello, world']
# Out:
# ['h', 'e', 'l', 'l', 'o', ',', ' ', 'w', 'o', 'r', 'l', 'd']

# %% [markdown]
# ## String split()

# %%
s = "harvard university"
s.split(' ')
# Out:
# ['harvard', 'university']

# %%
s2 = s.split(' ')
s2
# Out:
# ['harvard', 'university']

# %%
s2[1][0:]
# Out:
# 'university'

# %% [markdown]
# ### String methods
# isalnum()
#
# isalpha()
#
# isdigit()
#
# islower()
#
# isspace()
#
# isupper()

# %%
'hello, world'.isalnum()
# Out:
# False

# %%
'helloworld'.isalnum()
# Out:
# True

# %%
'123'.isdigit()
# Out:
# True

# %%
'abc'.isdigit()
# Out:
# False

# %%
'abc'.islower()
# Out:
# True

# %%
'abc'.isupper()
# Out:
# False

# %%
'ABC'.isupper()
# Out:
# True

# %%
'ABC'.isalpha()
# Out:
# True

# %%
'abc123'.isalpha()
# Out:
# False

# %% [markdown]
# ## Searching strings
# endswith(substring)
#
# find(substring)
#
# startswith(substring)
#
# replace(old_string, new_string)

# %%
"www.harvard.edu".endswith(".edu")
# Out:
# True

# %%
"www.harvard.edu".endswith(".net")
# Out:
# False

# %%
"www.harvard.edu".startswith("www")
# Out:
# True

# %%
'www.yale.edu'.replace('yale', 'harvard')
# Out:
# 'www.harvard.edu'
