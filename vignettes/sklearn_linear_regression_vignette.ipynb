# %% [markdown]
# # SciKit-Learn Linear Regression Vignette
#
# December 22, 2022
#
# Vignette: SciKit-Learn Linear Regression
#
# @author: Oscar A. Trevizo
#
# ### References
# 1. SciKit-Learn Linear Regression documentation (accessed Dec. 22, 2022)
#    https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# ### Methods (see reference)
# - fit(X, y[, sample_weight]) Fit linear model.
# - get_params([deep]) Get parameters for this estimator.
# - predict(X) Predict using the linear model.
# - score(X, y[, sample_weight]) Return the coefficient of determination of the prediction.
# - set_params(**params) Set the parameters of this estimator.

# %% [markdown]
# # Linear Regresion

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

sns.set_style("darkgrid")

# %% [markdown]
# # Create data

# %%
# Make variables have the same space 0 to 100 and generate 50 points

# Start with the dependent variable
y = np.linspace(0, 100, 50) + np.random.normal(scale=15, size=50)

# Now independent variables var1 and var2
var1 = np.linspace(0, 100, 50) + np.random.normal(scale=20, size=50)

var2 = np.linspace(0, 100, 50) + np.random.normal(scale=10, size=50)

# %% [markdown]
# # Build the DataFrame

# %%
df = pd.DataFrame({'y':y, 'var1':var1, 'var2':var2})

# %% [markdown]
# # Plot linear model

# %%
sns.lmplot(x='var1', y='y', data=df)

sns.lmplot(x='var2', y='y', data=df)

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Create train, test datasets

# %%
# sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=40)

# %%
y_test.shape
# Out:
# (10,)

# %% [markdown]
# ## Fit the model

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predict

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([ 74.95775915,  62.87741652,  78.80536031,  90.36908364,
#        106.03069756,  34.75564724,  54.45807385,  21.69774043,
#         23.90537309,  22.68214518])

# %% [markdown]
# ## Score

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ## Coefficients and Intercept

# %%
model.coef_
# Out:
# array([1.00000000e+00, 1.14457501e-16, 8.78259049e-17])

# %%
model.intercept_
# Out:
# 0.0
