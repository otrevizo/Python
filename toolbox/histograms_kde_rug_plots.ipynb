# %% [markdown]
# # Histograms, Kernel Density Estimation (KDE)m and Rug plots
#
# December 26, 2022
#
# @author: Oscar A. Trevizo
#
# ### References
# 1. "Pandas General Functions" (accessed Feb. 20, 2022) https://pandas.pydata.org/pandas-docs/stable/reference/general_functions.html
# 1. "Seaborn Statistical Data Visualization documentation" (accessed Dec. 29, 2022) https://seaborn.pydata.org/

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data from a csv

# %%
# https://www.kaggle.com/datasets/rishidamarla/fifa-players-ratings
# And specify which columns to load
df = pd.read_csv('../data/fifa_cleaned.csv', usecols = ['id', 'name', 'birth_date', 'age',
                                                'height_cm', 'weight_kgs', 'positions',
                                                'club_team', 'national_team', 'overall_rating',
                                                'wage_euro'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              17954 non-null  int64
#  1   name            17954 non-null  object
#  2   birth_date      17954 non-null  object
#  3   age             17954 non-null  int64
#  4   height_cm       17954 non-null  float64
#  5   weight_kgs      17954 non-null  float64
#  6   positions       17954 non-null  object
#  7   overall_rating  17954 non-null  int64
#  8   wage_euro       17708 non-null  float64
#  9   club_team       17940 non-null  object
#  10  national_team   857 non-null    object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# # KDE plots

# %%
vars = ['age', 'height_cm', 'weight_kgs', 'wage_euro']

fig, ax = plt.subplots(1, 4, figsize=(14,5))
ax = ax.flatten()

# Loop through variables
# We have one single lambda
for i, var in enumerate(vars):
    # title = str(bt)
    # Plote once
    ax[i].hist(df[var], bins=25, density=True)
    sns.kdeplot(x=df[var], ax=ax[i])
    sns.rugplot(x=df[var], ax=ax[i])
    ax[i].set_ylabel('frequency')
    ax[i].set_xlabel(var)
    ax[i].set_title('FIFA players')

# %%
##### Copyright 2022 Oscar Trevizo. All rights reserved.
