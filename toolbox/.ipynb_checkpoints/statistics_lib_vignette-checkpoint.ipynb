# %%
# -*- coding: utf-8 -*-
"""
Created on 2022-12-20
Revised on 2026-04-01

@author:       Oscar Trevizo
@institution:  Harvard Extension School — Graduate Data Science Program (2023)
@context:      Independent project — applying course concepts to real-world data
@environment:  Python 3.14.3 | myenv | MacBook Air M5

Statistics Library Vignette
============================

Description:
    Quick reference vignette for Python's built-in statistics module.
    Demonstrates core statistical functions on simple numeric lists
    without requiring NumPy, SciPy, or any external libraries.

    Functions demonstrated:
        st.mean()   — arithmetic mean
        st.stdev()  — sample standard deviation

    Note: For a full OO implementation of descriptive and inferential
    statistics using Python built-ins only, see descriptive_statistics_module.ipynb.

References:
    - Python statistics module (accessed Dec. 20, 2022):
      https://docs.python.org/3/library/statistics.html

Revision History:
    2022-12-20  Original development
                - Explored statistics module with st.__dict__
                - Demonstrated mean and stdev on numeric lists

    2026-04-01  Revision
                - Added module-level docstring (Cell [1])
                - Confirmed compatibility with Python 3.14.3 / myenv / M5
"""
# Out:
# "\nCreated on 2022-12-20\nRevised on 2026-04-01\n\n@author:       Oscar Trevizo\n@institution:  Harvard Extension School — Graduate Data Science Program (2023)\n@context:      Independent project — applying course concepts to real-world data\n@environment:  Python 3.14.3 | myenv | MacBook Air M5\n\nStatistics Library Vignette\n============================\n\nDescription:\n    Quick reference vignette for Python's built-in statistics module.\n    Demonstrates core statistical functions on simple numeric lists\n    without requiring NumPy, SciPy, or any external libraries.\n\n    Functions demonstrated:\n        st.mean()   — arithmetic mean\n        st.stdev()  — sample standard deviation\n\n    Note: For a full OO implementation of descriptive and inferential\n    statistics using Python built-ins only, see descriptive_statistics_module.ipynb.\n\nReferences:\n    - Python statistics module (accessed Dec. 20, 2022):\n      https://docs.python.org/3/library/statistics.html\n\nRevision 
# ...

# %%
import statistics as st

# %%
# Explorethe library
st.__dict__
# Out:
# {'__name__': 'statistics',
# ...

# %% [markdown]
# # Load data

# %%
# A numberic list
n = [1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5]

# %%
# Two more numeric lists we can compare
score_1 = [91, 83, 95, 72, 91, 85, 89, 82, 90, 79]
score_2 = [91, 85, 90, 81, 95, 92, 88, 94, 91, 75]

# %% [markdown]
# # Apply methods

# %%
st.mean(score_1)
# Out:
# 85.7

# %%
st.mean(n)
# Out:
# 6.0

# %%
st.stdev(n)
# Out:
# 3.0276503540974917
