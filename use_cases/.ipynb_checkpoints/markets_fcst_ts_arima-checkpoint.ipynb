# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May  9 2023
Revised on Wed Mar 25 2026

@author:       Oscar Trevizo
@institution:  Harvard Extension School — Graduate Data Science Program (2023)
@context:      Independent project — applying course concepts to financial data
@environment:  Python 3.14.3 | myenv | MacBook Air M5

Markets Forecast Using Time Series ARIMA Model
===============================================

Description:
    Time series analysis and forecast of SPY (S&P 500 ETF) using
    classical statistical methods including seasonal decomposition
    and Auto ARIMA modeling.

Revision History:
    2023-05-09  Original development
                - Harvard Graduate Certificate in Data Science
                - Data source: pandas_datareader / stooq

    2026-03-25  Major revision
                - Migrated data source to yfinance (pandas_datareader
                  deprecated on Python 3.14 / pandas 3.x)
                - Updated to Python 3.14.3 on MacBook Air M5
                - Added metadata documentation throughout
                - AI assistance: Claude (Anthropic) — March 2026
                  Used for debugging, library migration, and
                  code documentation guidance
"""
# Out:
# '\nCreated on Tue May  9 2023\nRevised on Wed Mar 25 2026\n\n@author:       Oscar Trevizo\n@institution:  Harvard Extension School — Graduate Data Science Program (2023)\n@context:      Independent project — applying course concepts to financial data\n@environment:  Python 3.14.3 | myenv | MacBook Air M5\n\nMarkets Forecast Using Time Series ARIMA Model\n===============================================\n\nDescription:\n    Time series analysis and forecast of SPY (S&P 500 ETF) using\n    classical statistical methods including seasonal decomposition\n    and Auto ARIMA modeling.\n\nRevision History:\n    2023-05-09  Original development\n                - Harvard Graduate Certificate in Data Science\n                - Data source: pandas_datareader / stooq\n\n    2026-03-25  Major revision\n                - Migrated data source to yfinance (pandas_datareader\n                  deprecated on Python 3.14 / pandas 3.x)\n                - Updated to Python 3.14.3 on MacBook Air M5\n     
# ...

# %% [markdown]
# # SPY Stock Market Time Series Analysis & Forecast
# **Author:** Oscar Trevizo
# **Institution:** Harvard Graduate Certificate in Data Science
# **Date:** March 2026
#
# ---
#
# ## Overview
#
# This notebook performs a **time series analysis and forecast** of the SPY ETF
# (S&P 500 Index Fund) using classical statistical methods. It demonstrates the
# full data science pipeline from data acquisition to forecast visualization.
#
# ### What This Notebook Covers
#
# | Step | Description | Tools |
# |------|-------------|-------|
# | **1. Data Acquisition** | Download SPY historical prices | `yfinance` |
# | **2. Exploratory Analysis** | Visualize price history and distributions | `matplotlib`, `seaborn` |
# | **3. Decomposition** | Separate trend, seasonal, and residual components | `statsmodels` |
# | **4. Model Selection** | Automatically find best ARIMA parameters | `pmdarima.auto_arima` |
# | **5. Forecast** | Predict 100 trading days forward | `ARIMA(1,1,1)(2,1,0)[12]` |
#
# ### Libraries Used
# ```python

# %%
# %% Load the Libraries
#
import pandas as pd
from pandas.api.types import is_numeric_dtype
from pandas import DataFrame, date_range, concat
import numpy as np
from math import log, sqrt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.metrics import mean_squared_error
import scipy.stats as ss
from scipy.stats import pearsonr
import statsmodels.api as sm
import statsmodels.tsa.seasonal as sts
from statsmodels.tsa.seasonal import STL
import statsmodels.tsa.arima_process as arima
from statsmodels.tsa.arima.model import ARIMA, ARIMAResults
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import VAR
import statsmodels.graphics.tsaplots as splt
import pmdarima as pm
from pmdarima import model_selection
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# Old code (May 2023):
# pandas-datareader is abandoned and broken on Python 3.14 + pandas 3.x.
# https://anaconda.org/anaconda/pandas-datareader
# conda install -c anaconda pandas-datareader
# or pip install pandas-datareader
# import pandas_datareader.data as rdr

# New code (March 2026):
import yfinance as yf

import datetime as dt


# Create a date out of the sting in the file.
from datetime import datetime

# %% [markdown]
# # Load the libraries

# %%
# Assign start and end dates to collect stock data
start = dt.datetime(2022,1,1)
# end = dt.datetime(2026,3,24)
# end = dt.datetime.now()
end = dt.datetime.today().date()

# %%
# Old code May 2023
# Get stock data from stooq... use 'qqq' or 'spy' or other individual stock
# df = rdr.DataReader("spy", "stooq", start, end)
# df.describe()

# New code Mar 2026
df = yf.download("SPY", start=start, end=end)

# Flatten the MultiIndex columns from yfinance
df.comlumns = df.columns.droplevel(1)

# Make Date a regular column
df = df.reset_index()

# Stooq returned the data in reverse order, so the following line is not required
# But it does not hurt
df = df.sort_index(ascending=True)

df.describe()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                  Date        Close         High          Low  \
# Ticker                               SPY          SPY          SPY
# count                  1064  1064.000000  1064.000000  1064.000000
# mean    2024-02-14 22:07:40   497.089888   499.843453   493.929798
# min     2022-01-03 00:00:00   340.252777   343.363691   332.189260
# 25%     2023-01-24 18:00:00   399.780380   403.351037   396.622809
# 50%     2024-02-14 12:00:00   485.095367   486.959080   482.109738
# 75%     2025-03-10 06:00:00   585.050476   587.293393   580.863823
# max     2026-03-31 00:00:00   693.595764   695.939393   692.049990
# std                     NaN   105.025037   105.048400   104.931877
#
# Price          Open        Volume
# Ticker          SPY           SPY
# count   1064.000000  1.064000e+03
# mean     497.015424  7.734882e+07
# min      333.238958  2.604870e+07
# 25%      400.602862  5.929678e+07
# ...

# %%
# Diagnose the df structure
print(df.columns)
print(df.columns.nlevels)
print(df.head(2))
# Out:
# MultiIndex([(  'Date',    ''),
#             ( 'Close', 'SPY'),
#             (  'High', 'SPY'),
#             (   'Low', 'SPY'),
#             (  'Open', 'SPY'),
#             ('Volume', 'SPY')],
#            names=['Price', 'Ticker'])
# 2
# Price        Date       Close        High         Low        Open    Volume
# Ticker                    SPY         SPY         SPY         SPY       SPY
# 0      2022-01-03  450.644409  450.776491  447.003119  449.314292  72668200
# 1      2022-01-04  450.493530  452.785876  448.635143  452.068926  71178700

# %% [markdown]
# ## Metadata Notes — DataFrame Column Index
#
# After `yf.download()`, the DataFrame contains a **MultiIndex** with an extra
# label called `'Price'` sitting *above* the column names. This is an example of
# **structural metadata** — data that describes how the data is organized,
# not the data itself.
#
# ### Three Layers of DataFrame Metadata
#
# | Layer | Code | Value | Meaning |
# |-------|------|-------|---------|
# | Column index name | `df.columns.name` | `'Price'` | Label *above* column names |
# | Column names | `df.columns` | `Close, High, Low...` | Actual column names |
# | Row index name | `df.index.name` | `'Date'` | Label for the row index |
#
# ### Metadata Types (Big Picture)
#
# | Type | Description | Example Here |
# |------|-------------|--------------|
# | **Structural** | How data is organized | MultiIndex, column names, dtypes |
# | **Descriptive** | What the data means | SPY = S&P 500 ETF, Close = closing price |
# | **Administrative** | Ownership, lineage, provenance | Source: Yahoo Finance via `yfinance` |
# | **Statistical** | Shape and distribution | `df.describe()` — 1059 rows, $340–$693 range |
#
# ### Metadata Map
# ```
# Metadata types you'll work with:
# │
# ├── Structural     → column names, dtypes, index labels (what you just saw)
# ├── Descriptive    → what the data means, units, source (SPY from Yahoo Finance)
# ├── Administrative → when created, who owns it, lineage/provenance
# └── Statistical    → describe(), distributions, missing values, outliers
# ```
#
# ### The Fix
# ```python
# df.columns.name = None   # removes the 'Price' label — cosmetic/metadata cleanup
#                          # does NOT change the data, only the structural metadata
# ```
#
# > 💡 **Key insight:** A *data product* is a dataset **plus its metadata** —
# > packaged so that others (or future you) can trust and use it without guessing.

# %%
# Remove the metadata to have a clean DataFrame
# The 'Price' is sitting abopve the column names (i.e., df.columns.name)
# That means it is the label for the columns index itself

# Thus code needs to run all together again
df = yf.download("SPY", start=start, end=end)
df = df.droplevel(1, axis=1)   # better than df.columns.droplevel(1)
df.index = pd.to_datetime(df.index)  # ensure DatetimeIndex
df.columns.name = None         # remove the 'Price' label
df = df.sort_index(ascending=True)

print(df.columns)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='str')
#                  Close        High         Low        Open     Volume
# Date
# 2022-01-03  450.644409  450.776491  447.003119  449.314292   72668200
# 2022-01-04  450.493530  452.785876  448.635143  452.068926   71178700
# 2022-01-05  441.843048  450.899148  441.748708  450.125599  104538900
# 2022-01-06  441.428040  444.144873  439.060239  441.380884   86858900
# 2022-01-07  439.682831  442.616643  438.324414  441.437464   85111600

# %%
fig, ax = plt.subplots(figsize=(10, 10))
fig.subplots_adjust(bottom=0.4,top=0.7)
ax = sns.lineplot(x='Date', y='Close', data=df, errorbar=None, ax=ax)
_=ax.set_title('SPY', fontsize=14)
_=ax.set_xlabel('Date', fontsize=8)
_=ax.set_ylabel('Close', fontsize=8)
_=ax.tick_params(labelsize=8)
plt.show()

# %%
# %%% Plot the time series
plt.figure(figsize=(10, 5))
plt.plot(df.index, df.Close, label='SPY')
plt.legend()
plt.show()

# %%
dec = sts.seasonal_decompose(df.Close, extrapolate_trend = 'freq', period = 12)

# %%
ts = pd.DataFrame({'resid': dec.resid, 
                         'trend': dec.trend, 
                         'seasonal': dec.seasonal},
                       index = df.index)

plt.figure(figsize=(8, 4))
plt.plot(ts.index, ts.trend, label='Trend')
plt.plot(ts.index, ts.resid, label='Residual')
plt.plot(ts.index, ts.seasonal, label='Seasonal')
#plt.ylim([-2.5, 12])
plt.legend()
plt.show()

# %% [markdown]
# # Auto ARIMA Model

# %%
best_model = pm.auto_arima(ts.trend, start_p=1, start_q=1,
                             max_p=3, max_q=3, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             information_criterion = 'bic',
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(1,1,1)(0,1,1)[12]             : BIC=inf, Time=1.33 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : BIC=4270.568, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : BIC=1782.715, Time=0.25 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : BIC=inf, Time=0.85 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : BIC=2334.707, Time=0.05 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : BIC=1524.959, Time=0.39 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : BIC=inf, Time=1.06 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : BIC=inf, Time=2.06 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : BIC=3902.084, Time=0.10 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : BIC=1244.897, Time=0.86 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : BIC=1480.801, Time=0.26 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : BIC=inf, Time=2.98 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : BIC=inf, Time=2.47 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : BIC=1187.918, Time=0.65 sec
# ...

# %% [markdown]
# ## Auto ARIMA Model — SPY Trend Analysis
#
# `auto_arima` from `pmdarima` performs a **stepwise search** to find the best
# ARIMA model by minimizing the **BIC (Bayesian Information Criterion)** score.
# Lower BIC = better model (balances fit quality vs. model complexity).
#
# ### Best Model Selected: ARIMA(2,1,3)(2,1,0)[12]
# ```
# ARIMA  (2, 1, 3) (2, 1, 0) [12]
#         |  |  |   |  |  |    |
#         |  |  |   |  |  |    +-- seasonality period = 12 months
#         |  |  |   |  |  +------- seasonal MA order = 0
#         |  |  |   |  +---------- seasonal differencing = 1
#         |  |  |   +------------- seasonal AR order = 2
#         |  |  +----------------- MA order = 3 (Moving Average)
#         |  +-------------------- differencing = 1 (makes series stationary)
#         +----------------------- AR order = 2 (AutoRegressive)
# ```
#
# ### Parameter Interpretation
#
# | Parameter | Value | Meaning |
# |-----------|-------|---------|
# | AR(2) | p=2 | Uses **2 lags** to predict next value |
# | d=1 | Differencing=1 | SPY trend is non-stationary — 1 difference makes it stationary |
# | MA(3) | q=3 | Uses **3 past errors** to correct predictions |
# | Seasonal AR(2) | P=2 | Looks back **2 seasonal periods** (24 months) |
# | Seasonal d=1 | D=1 | Strong seasonal pattern confirmed |
# | Seasonal MA(0) | Q=0 | No seasonal moving average needed |
# | Period | m=12 | Monthly seasonality |
#
# ### What This Tells Us About SPY
#
# | Insight | Detail |
# |---------|--------|
# | **Non-stationary** | `d=1` confirms stock prices follow a random walk — expected |
# | **Seasonal pattern** | `D=1` confirms recurring annual cycles in the trend |
# | **Long seasonal memory** | Seasonal AR(2) means the model looks back 24 months |
# | **Richer short-term structure** | MA(3) captures more complex error-correction vs. MA(1) in prior runs |
#
# ### Note on Run-to-Run Variability
#
# A previous run of this notebook produced `ARIMA(1,1,1)(2,1,0)[12]` as the
# best model; this run produced `ARIMA(2,1,3)(2,1,0)[12]`. Both are legitimate
# results. Several factors explain why `auto_arima` may converge to a different
# model across runs:
#
# - **Data window shifts.** Each new run fetches a slightly longer or
#   shifted price history from `yfinance`, changing the statistical
#   structure of the trend component.
# - **Market noise.** Equity prices contain a very high noise-to-signal
#   ratio. Small changes in the trailing data can tip the BIC balance
#   between two closely competing models.
# - **Stepwise search sensitivity.** `auto_arima` uses a greedy stepwise
#   algorithm (not an exhaustive grid search). The path it follows
#   through the model space is sensitive to starting conditions and the
#   exact numerical values in the series.
# - **Seasonal decomposition upstream.** The model fits the `trend`
#   component extracted by `seasonal_decompose`. Any variation in that
#   component propagates into the ARIMA search.
#
# This instability is itself informative: it reflects the inherent
# unpredictability of financial time series. One mitigation is to fix the
# date range explicitly (rather than using a rolling end date) so the
# dataset is identical across runs — see the note in the data-loading cell.
#
# ### BIC Score Comparison (Top 5 — current run)
#
# | Model | BIC |
# |-------|-----|
# | **ARIMA(2,1,3)(2,1,0)[12]** | (best — current run) |
# | ARIMA(1,1,1)(2,1,0)[12] | (best — prior run) |
# | other candidates | tested by stepwise search |
#
# > **Note:** Exact BIC values from the current run appear in the `auto_arima`
# > output above. The prior-run best BIC was 1187.434 for ARIMA(1,1,1)(2,1,0)[12].
# > Models returning `BIC=inf` failed to converge — common with higher-order
# > MA terms on financial time series data.

# %% [markdown]
# # Predict

# %%
# %% Predict
num_preds = 100
# Predictions to compare results to actuals
prediction = pd.DataFrame({'pred': best_model.predict(n_periods=num_preds)})

# Make it a time series => Set the index to the proper dates
# pred_start_date = pd.to_datetime('2023-05-10')
pred_start_date = end
# freq 'B' Business days instead of 'D' for every day of the week that includes weekdays
pred_dates = pd.date_range(start=pred_start_date, periods=num_preds, freq='B')
prediction.set_index(pred_dates, inplace = True)
prediction.tail()
# Out:
#                   pred
# 2026-08-12  449.794096
# 2026-08-13  447.746232
# 2026-08-14  445.813036
# 2026-08-17  443.807621
# 2026-08-18  441.643411

# %%
# Plot results
plt.figure(figsize=(8, 4))
plt.plot(ts.index, ts.trend, label='Trend')
plt.plot(prediction.index, prediction.pred, label='Prediction')
#plt.ylim([4, 12])
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusions
#
# ### Model Selected: ARIMA(2,1,3)(2,1,0)[12]
#
# `auto_arima` performed a stepwise search across model combinations and selected
# `ARIMA(2,1,3)(2,1,0)[12]` as the best model based on minimum BIC score in
# the current run.
#
# ### Note on Run-to-Run Variability
#
# A prior run of this notebook selected `ARIMA(1,1,1)(2,1,0)[12]` (BIC 1187.434).
# The current run converged on `ARIMA(2,1,3)(2,1,0)[12]`. This is not an error —
# it reflects a known characteristic of fitting ARIMA models to financial time
# series data:
#
# - `yfinance` fetches data up to the current date, so the training window
#   grows with each run. Even a few additional weeks of volatile market
#   data can shift the BIC landscape enough to favor a different model.
# - Equity price series carry a high noise-to-signal ratio. The margin
#   between closely competing models can be very small.
# - The `auto_arima` stepwise algorithm is greedy by design; it does not
#   guarantee finding the global BIC minimum, and its path is sensitive
#   to the exact data it receives.
#
# To make results reproducible, fix the `end` date in the data-loading cell
# so the dataset is identical across runs.
#
# ### Forecast Results (100 Trading Days)
#
# | Metric | Value |
# |--------|-------|
# | **Forecast horizon** | 100 trading days (~5 months) |
# | **Forecast start** | March 2026 |
# | **Forecast end** | August 2026 |
# | **Trend direction** | Negative (declining) |
#
# ### Key Observations
#
# | Observation | Detail |
# |-------------|--------|
# | **Non-stationary series** | `d=1` confirms SPY follows a random walk |
# | **Seasonal pattern** | `D=1` confirms annual cycles in the trend |
# | **Negative forecast** | Model projects declining trend based on recent history |
# | **Model limitation** | ARIMA is univariate — sees price history only |
#
# ### Important Limitations
#
# ARIMA is a **univariate time series model** — it forecasts based solely on
# historical price patterns. It cannot factor in:
#
# - Macroeconomic indicators (GDP, inflation, employment)
# - Federal Reserve monetary policy decisions
# - Corporate earnings reports
# - Geopolitical events and market sentiment
# - Breaking news and black swan events
#
# The negative forecast reflects the **recent downward trend** in the training
# data. The market may behave differently based on factors outside this model's
# scope. This is a **mathematical exercise**, not investment advice.
#
# ### Next Steps
#
# | Project | Description | Tools |
# |---------|-------------|-------|
# | **Multivariate model** | Add economic indicators alongside price | `VAR` (already imported) |
# | **Deep learning forecast** | Compare ARIMA vs LSTM neural network | `tensorflow`, `keras` |
# | **Sentiment analysis** | Incorporate news sentiment into forecast | `langchain`, `anthropic` |
# | **Data product** | Package this analysis with full metadata | `pydantic`, `pyarrow` |
# | **Fixed date range** | Pin `end` date to stabilize model selection across runs | `yfinance` |
#
# **Portfolio note:** This notebook is part of a broader data science
# portfolio developed during a sabbatical following 30 years in telecom
# analytics (Lucent/ALU/Nokia). It demonstrates classical time series methods
# as a foundation for more advanced multivariate and AI-enhanced forecasting models.
